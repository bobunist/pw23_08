# %% [markdown]
# # Задание 1

# %%
# %run main.py
# Out:
# Dataset 1
# K=1:
# Accuracy: 0.94
# Precision: 0.94
# Recall: 0.94
# F1-Score: 0.94
# Confusion Matrix:
# [[14  1]
#  [ 1 16]]
# ---
# K=2:
# Accuracy: 0.94
# Precision: 1.00
# Recall: 0.88
# F1-Score: 0.94
# Confusion Matrix:
# [[15  0]
#  [ 2 15]]
# ---
# K=3:
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# F1-Score: 1.00
# Confusion Matrix:
# [[15  0]
#  [ 0 17]]
# ---
# K=4:
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# F1-Score: 1.00
# Confusion Matrix:
# [[15  0]
#  [ 0 17]]
# ---
# K=5:
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# F1-Score: 1.00
# Confusion Matrix:
# [[15  0]
#  [ 0 17]]
# ---
# K=6:
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# F1-Score: 1.00
# Confusion Matrix:
# [[15  0]
#  [ 0 17]]
# ---
# K=7:
# Accuracy: 0.94
# Precision: 0.89
# Recall: 1.00
# F1-Score: 0.94
# Confusion Matrix:
# [[13  2]
#  [ 0 17]]
# ---
# K=8:
# Accuracy: 0.94
# Precision: 0.89
# Recall: 1.00
# F1-Score: 0.94
# Confusion Matrix:
# [[13  2]
#  [ 0 17]]
# ---
# ...

# %% [markdown]
# # Задание 2

# %%
# %run task2.py
# Out:
# 	Precision	Recall	F1-Score	Support
# Cat	0.67		0.67	0.67		4
# Fish	0.83		0.56	0.67		5
# Hen	0.57		1.00	0.73		4
#
# Accuracy: 0.52
# Macro Avg	 0.69		0.74	0.69		25
# Weighted Avg	 0.69		0.76	0.69		25

# %% [markdown]
# # Задание 3

# %% [markdown]
# датасет https://www.kaggle.com/datasets/joebeachcapital/medical-insurance-costs

# %%
# %run task3.py
# Out:
#     Model  R2 (Training)  R2 (Testing)
# 0     age       0.079367      0.124090
# 1     bmi       0.038934      0.039702
# 2  smoker       0.608498      0.660249
# Лучший R2 на тестовом наборе для smoker
